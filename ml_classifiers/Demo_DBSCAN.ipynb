# %% [markdown]
# # DBSCAN DSI Spring 2026 Symposium Demo

# %%
# !pip install jarvis-tools
# !pip install pandas
# Out:
# Requirement already satisfied: jarvis-tools in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (2026.1.10)
# Requirement already satisfied: numpy>=1.20.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (2.4.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (1.17.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (3.10.8)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (1.5.3)
# Requirement already satisfied: requests>=2.23.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (2.32.5)
# Requirement already satisfied: toolz>=0.9.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (1.1.0)
# Requirement already satisfied: xmltodict>=0.11.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (1.0.4)
# Requirement already satisfied: tqdm>=4.41.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (4.67.3)
# Requirement already satisfied: scikit-learn in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jarvis-tools) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from matplotlib>=3.0.0->jarvis-tools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->jarvis-tools) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from requests>=2.23.0->jarvis-tools) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from requests>=2.23.0->jarvis-tools) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from requests>=2.23.0->jarvis-tools) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from requests>=2.23.0->jarvis-tools) (2026.1.4)
# Requirement already satisfied: colorama in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from tqdm>=4.41.1->jarvis-tools) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from scikit-learn->jarvis-tools) (3.6.0)
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: pandas in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from jarvis.db.figshare import data #retrieve data of materials
import pandas as pd #for data manipulation and creating dataframes which are like tables
df=pd.DataFrame(data('dft_3d')) #3d dataset includes geometric and visual properties
# Out:
# Obtaining 3D dataset 76k ...
# Reference:https://doi.org/10.1016/j.commatsci.2025.114063
# Other versions:https://doi.org/10.6084/m9.figshare.6815699
# Loading the zipfile...
# Loading completed.

# %%
#Based on the Accelerated Discovery of Efficient Solar Cell Materials Using Quantum and Machine Learning Methods,
#we are interested in materials with SLME values > 10%
#remove the data that does not have SLME values
df_slme = df[df['slme'] != 'na'].copy()
#to compare the slme values we need to convert it to a float
df_slme.loc[:,'slme'] = df_slme['slme'].astype(float)
#add a new column slme_10 that has a 1 if slme value >=10.0 otherwise 0
df_slme.loc[:,'slme_10'] = (df_slme['slme'] >= 10.0).astype(int)
df_slme #display the data
# Out:
#                 jid spg_number spg_symbol   formula  formation_energy_peratom  \
# 20      JVASP-60702         61       Pbca  PdSe8Cl2                  -0.15071
# 23      JVASP-86436        148        R-3    LiSbF6                  -2.61531
# 24       JVASP-1372        216      F-43m      AlAs                  -0.57639
# 25      JVASP-14873        221      Pm-3m      SrB6                  -0.49796
# 26      JVASP-28397         53       Pmna       SiS                  -0.38924
# ...             ...        ...        ...       ...                       ...
# 75345  JVASP-152501         88     I4_1/a     Li4HN                  -0.56067
# 75566  JVASP-156465        216      F-43m    PmCdGa                  -0.44795
# 75593  JVASP-156446        216      F-43m    HfInAu                  -0.39541
# 75961  JVASP-156363        216      F-43m    HfPdPb                  -0.42246
# 75972  JVASP-156295        164      P-3m1  NaMg2Sb2                  -0.40743
#
#             func  optb88vdw_bandgap  \
# 20     OptB88vdW              1.197
# 23     OptB88vdW              4.907
# 24     OptB88vdW              1.681
# 25     OptB88vdW              0.016
# 26     OptB88vdW              0.658
# ...          ...                ...
# 75345  OptB88vdW              2.120
# 75566  OptB88vdW              0.050
# 75593  OptB88vdW              0.441
# 75961  OptB88vdW              0.310
# 75972  OptB88vdW              0.000
#
#                                                    atoms   slme  \
# 20     {'lattice_mat': [[9.067075684180468, -0.0, 0.0...   32.6
# 23     {'lattice_mat': [[4.509029640475962, 0.0564034...  21.81
# 24     {'lattice_mat': [[3.5058938597621094, -3.08124...  17.06
# 25     {'lattice_mat': [[4.191262576674699, 0.0, -0.0...   6.11
# 26     {'lattice_mat': [[0.0, -3.9587610833154616, 0....  31.59
# ...                                                  ...    ...
# 75345  {'lattice_mat': [[-2.4135795217419225, 2.41357...   2.94
# 75566  {'lattice_mat': [[-0.0, 3.3728792894010553, 3....   5.84
# 75593  {'lattice_mat': [[0.0, 3.225842292903002, 3.22...  13.63
# 75961  {'lattice_mat': [[0.0, 3.218164909882003, 3.21...   5.84
# 75972  {'lattice_mat': [[4.747449533252537, -1.760229...    0.0
#
#       magmom_oszicar  ... poisson  \
# 20               0.0  ...      na
# 23               0.0  ...      na
# 24               0.0  ...    0.25
# 25               0.0  ...     0.2
# 26                na  ...    0.39
# ...              ...  ...     ...
# 75345            0.0  ...      na
# 75566            0.0  ...      na
# 75593            0.0  ...      na
# 75961            0.0  ...      na
# 75972            0.0  ...    0.38
#
#                                                raw_files nat bulk_modulus_kv  \
# 20     [DFPT,JVASP-60702.zip,https://ndownloader.figs...  44              na
# 23     [OPT-LOPTICS,JVASP-86436.zip,https://ndownload...   8              na
# 24     [FD-ELAST,JVASP-1372.zip,https://ndownloader.f...   2           68.87
# 25     [FD-ELAST,JVASP-14873.zip,https://ndownloader....   7           150.6
# 26     [FD-ELAST,JVASP-28397.zip,https://ndownloader....   8            6.63
# ...                                                  ...  ..             ...
# 75345                                                 []  12              na
# 75566                                                 []   3              na
# 75593                                                 []   3              na
# 75961                                                 []   3              na
# 75972                                                 []   5           29.87
#
#       shear_modulus_gv mbj_bandgap hse_gap              reference     search  \
# 20                  na          na      na              mp-567437  -Cl-Pd-Se
# 23                  na          na      na                mp-3980   -F-Li-Sb
# 24               42.58       2.276      na                mp-2172     -Al-As
# 25               125.7       0.256      na                 mp-242      -B-Sr
# 26                5.44       0.959      na             mp-1023900      -S-Si
# ...                ...         ...     ...                    ...        ...
# 75345               na       3.183      na  auid-ac967cceb96b5f2b    -H-Li-N
# 75566               na       0.113      na                 953260  -Cd-Ga-Pm
# 75593               na       0.469      na                 947461  -Au-Hf-In
# 75961               na       0.278      na                 897636  -Hf-Pb-Pd
# 75972             8.78      14.703      na                1284992  -Mg-Na-Sb
#
#       slme_10
# 20          1
# 23          1
# 24          1
# 25          0
# 26          1
# ...       ...
# 75345       0
# 75566       0
# 75593       1
# 75961       0
# 75972       0
#
# [9770 rows x 65 columns]

# %%
#importing libraries for clustering and visualization
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

# %%
features = df_slme[['optb88vdw_bandgap', 
               'formation_energy_peratom', 
               'magmom_oszicar',
               'spillage', 
               'kpoint_length_unit', 
               'maxdiff_mesh', 
               'maxdiff_bz', 
               'encut',
               'optb88vdw_total_energy', 
               'epsx', 
               'epsy', 
               'epsz', 
               'mepsx', 
               'mepsy',
               'mepsz', 
               'magmom_outcar', 
               'max_efg', 
               'avg_elec_mass', 
               'avg_hole_mass',
               'dfpt_piezo_max_eij', 
               'dfpt_piezo_max_dij',
               'dfpt_piezo_max_dielectric',
               'dfpt_piezo_max_dielectric_electronic',
               'dfpt_piezo_max_dielectric_ionic', 
               'max_ir_mode', 
               'min_ir_mode',
               'n-Seebeck', 
               'p-Seebeck', 
               'n-powerfact', 
               'p-powerfact', 
               'ncond',
               'pcond',
               'nkappa', 
               'pkappa', 
               'ehull', 
               'Tc_supercon',
               'exfoliation_energy', 
               'density', 
               'poisson', 
               'nat', 
               'bulk_modulus_kv',
               'shear_modulus_gv', 
               'mbj_bandgap', 
               'hse_gap']]

# %%
#count columns df_slme 
print("Number of data points in df_slme:", len(features))
print("Number of features in df_slme:", len(features.columns))
# Out:
# Number of data points in df_slme: 9770
# Number of features in df_slme: 44

# %%
#take only numeric columns for clustering and scale the data because of different units and ranges of features
numeric_df = features.select_dtypes(include=[np.number])
numeric_df = StandardScaler().fit_transform(numeric_df) #standardize features by removing the mean and scaling to unit variance
df_scaled = pd.DataFrame(numeric_df, columns=features.select_dtypes(include=[np.number]).columns) #create a new dataframe with scaled numeric data
df_scaled.head() #display the first few rows of the scaled dataframe
# Out:
#    optb88vdw_bandgap  formation_energy_peratom  optb88vdw_total_energy  \
# 0          -0.511867                  1.204826                0.891860
# 1           1.557224                 -1.087660                0.307007
# 2          -0.241937                  0.808873                0.103603
# 3          -1.170519                  0.881826               -1.065560
# 4          -0.812471                  0.982954               -0.146273
#
#       ehull   density       nat
# 0 -0.408781 -0.141229  4.540904
# 1 -0.416390 -0.372328 -0.399784
# 2 -0.382627 -0.562473 -1.223232
# 3 -0.416390 -0.644381 -0.537025
# 4  0.164718 -2.012448 -0.399784

# %%
db = DBSCAN(eps=0.8, min_samples=10).fit(df_scaled) #DBSCAN clustering with specified parameters
#eps is the radius to be considered for neighboring points
#min_samples is the minimum number of points required to form a dense region (cluster)
labels = db.labels_ #get cluster labels assigned to each data point
#Masks are used for filtering data, visualization of different points , analysis of properties of core and non core, and efficiently accessing subsets of data points based on their cluster membership and density status.
from numpy import number


core_samples_mask = np.zeros_like(labels, dtype=bool) #create a boolean mask to identify if part of a dense cluster
core_samples_mask[db.core_sample_indices_] = True #mark core samples in the mask

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0) #calculate number of clusters, excluding noise points labeled as -1


print('Number of clusters: %d' % n_clusters_) #print the number of clusters found
print('Silhouette Coefficient: %0.3f' % metrics.silhouette_score(df_scaled, labels)) #calculate and print the silhouette coefficient to evaluate clustering quality
# Out:
# Number of clusters: 7
# Silhouette Coefficient: -0.117

# %%
#Apply PCA to reduce to 3 dimensions for visualization
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

pca = PCA(n_components=3)
df_pca = pca.fit_transform(df_scaled)
df_pca = pd.DataFrame(df_pca, columns=['PC1', 'PC2', 'PC3'])

# Show feature contributions to principal components
components_df = pd.DataFrame(
    pca.components_.T,
    columns=['PC1', 'PC2', 'PC3'],
    index=features.select_dtypes(include=[np.number]).columns
)

print("Feature Contributions to Principal Components:")
print("\nTop contributors to PC1:")
print(components_df['PC1'].abs().nlargest(5))
print("\nTop contributors to PC2:")
print(components_df['PC2'].abs().nlargest(5))
print("\nTop contributors to PC3:")
print(components_df['PC3'].abs().nlargest(5))

print("\nVariance explained by each component:")
for i, var in enumerate(pca.explained_variance_ratio_):
    print(f"PC{i+1}: {var*100:.2f}%")
# Out:
# Feature Contributions to Principal Components:
#
# Top contributors to PC1:
# formation_energy_peratom    0.556105
# optb88vdw_bandgap           0.494813
# optb88vdw_total_energy      0.484701
# nat                         0.353921
# ehull                       0.290634
# Name: PC1, dtype: float64
#
# Top contributors to PC2:
# density                     0.815437
# optb88vdw_bandgap           0.382598
# ehull                       0.268091
# formation_energy_peratom    0.208370
# nat                         0.192466
# Name: PC2, dtype: float64
#
# Top contributors to PC3:
# ehull                       0.746993
# optb88vdw_total_energy      0.456037
# nat                         0.425539
# formation_energy_peratom    0.226194
# optb88vdw_bandgap           0.042237
# Name: PC3, dtype: float64
#
# Variance explained by each component:
# PC1: 35.22%
# PC2: 21.25%
# PC3: 16.60%

# %%
# !pip install plotly nbformat ipywidgets
# Out:
# Requirement already satisfied: plotly in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (6.6.0)
# Requirement already satisfied: nbformat in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (5.10.4)
# Requirement already satisfied: ipywidgets in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (8.1.8)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from plotly) (2.18.1)
# Requirement already satisfied: packaging in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from plotly) (26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipywidgets) (9.10.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.2)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Users\Maria P\LUMENS-PV\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#Apply PCA to reduce to 3 dimensions for interactive visualization with Plotly
from sklearn.decomposition import PCA
import plotly.graph_objects as go

pca = PCA(n_components=3)
df_pca = pca.fit_transform(df_scaled)
df_pca = pd.DataFrame(df_pca, columns=['PC1', 'PC2', 'PC3'])

# Create traces for each cluster
fig = go.Figure()

unique_labels = set(labels)
colors_hex = [f'rgb{tuple([int(c*255) for c in plt.cm.Spectral(each)[:3]])}' 
              for each in np.linspace(0, 1, len(unique_labels))]

# Create a mapping of clusters to colors for legend
cluster_color_map = {}
for k, col_hex in zip(sorted(unique_labels), colors_hex):
    cluster_color_map[k] = col_hex

for k, col_hex in zip(sorted(unique_labels), colors_hex):
    if k == -1:
        continue  # Skip noise points for clarity
    class_member_mask = (labels == k)
    xy = df_pca[class_member_mask]
    
    # Get material indices for this cluster
    material_indices = df_slme[class_member_mask].index
    material_info = [f"Material ID: {idx}" for idx in material_indices]
    
    # Separate core and non-core points
    is_core = core_samples_mask[class_member_mask]
    
    # Plot core samples
    core_points = xy[is_core]
    core_materials = [material_info[i] for i, is_c in enumerate(is_core) if is_c]
    
    if len(core_points) > 0:
        fig.add_trace(go.Scatter3d(
            x=core_points['PC1'], y=core_points['PC2'], z=core_points['PC3'],
            mode='markers',
            name=f'Cluster {k} (core)',
            marker=dict(size=8, color=col_hex, opacity=1.0, line=dict(color='black', width=2)),
            text=core_materials,
            hovertemplate=f'<b>Cluster {k} (Core)</b><br>%{{text}}<br>PC1: %{{x:.3f}}<br>PC2: %{{y:.3f}}<br>PC3: %{{z:.3f}}<extra></extra>',
            legendgroup=f'cluster_{k}',
            showlegend=True
        ))
    
    # Plot non-core samples
    non_core_points = xy[~is_core]
    non_core_materials = [material_info[i] for i, is_nc in enumerate(is_core) if not is_nc]
    
    if len(non_core_points) > 0:
        fig.add_trace(go.Scatter3d(
            x=non_core_points['PC1'], y=non_core_points['PC2'], z=non_core_points['PC3'],
            mode='markers',
            name=f'Cluster {k} (border)',
            marker=dict(size=4, color=col_hex, opacity=0.6, line=dict(color='black', width=1.5)),
            text=non_core_materials,
            hovertemplate=f'<b>Cluster {k} (Border)</b><br>%{{text}}<br>PC1: %{{x:.3f}}<br>PC2: %{{y:.3f}}<br>PC3: %{{z:.3f}}<extra></extra>',
            legendgroup=f'cluster_{k}',
            showlegend=True
        ))

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
fig.update_layout(
    title=f'DBSCAN Clustering (3D) - Estimated number of clusters: {n_clusters_}<br><sub>Larger dots = core members | Smaller dots = border points</sub>',
    scene=dict(
        xaxis_title=f'Principal Component 1',
        yaxis_title=f'Principal Component 2',
        zaxis_title=f'Principal Component 3'
    ),
    width=1000,
    height=800,
    hovermode='closest',
    showlegend=True,
    
)
fig.show()

# Print label explanation
print("=" * 60)
print("DBSCAN Label Explanation:")
print("=" * 60)
print(f"Each point in the plot has a cluster label:")
print(f"  • Labels 0, 1, 2, ... = Cluster membership numbers")
print(f"  • Label -1 = Noise points (outliers not assigned to any cluster)")
print(f"\nPoint Types:")
print(f"  • Core members (larger dots): Points at the center of clusters")
print(f"  • Border points (smaller dots): Points on the edges of clusters")
print(f"\nCurrent Clustering Results:")
print(f"  • Number of clusters found: {n_clusters_}")
print(f"  • Number of noise points: {sum(labels == -1)}")
print(f"  • Total materials analyzed: {len(labels)}")
print("=" * 60)
# Out:
# ============================================================
# DBSCAN Label Explanation:
# ============================================================
# Each point in the plot has a cluster label:
#   • Labels 0, 1, 2, ... = Cluster membership numbers
#   • Label -1 = Noise points (outliers not assigned to any cluster)
#
# Point Types:
#   • Core members (larger dots): Points at the center of clusters
#   • Border points (smaller dots): Points on the edges of clusters
#
# Current Clustering Results:
#   • Number of clusters found: 7
#   • Number of noise points: 986
#   • Total materials analyzed: 9770
# ============================================================
